# %%
import pandas as pd
import numpy as np
import plotly
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# %run PLOTTING_FUNCTIONS.ipynb

# %%
# %run COSMETICS_DICTIONARIES.ipynb

# %%
# %run SOME_PREPROCESSING.ipynb

# %%
df = pd.read_csv('original_material/test.csv',sep=';')

# %%
# import predictions
litho_predictions = pd.read_csv('results/test_predictions.csv',sep=';')

# %%
df['PRED_LITHOLOGY'] = litho_predictions

# %%
df.head()
# Out:
#       WELL    DEPTH_MD         X_LOC      Y_LOC       Z_LOC         GROUP  \
# 0  15/9-14  480.628001  423244.50000  6461862.5 -455.624420  NORDLAND GP.
# 1  15/9-14  480.780001  423244.50000  6461862.5 -455.776428  NORDLAND GP.
# 2  15/9-14  480.932001  423244.50000  6461862.5 -455.928436  NORDLAND GP.
# 3  15/9-14  481.084001  423244.50000  6461862.5 -456.080444  NORDLAND GP.
# 4  15/9-14  481.236001  423244.53125  6461862.5 -456.232422  NORDLAND GP.
#
#   FORMATION     CALI  RSHA      RMED  ...  BS         ROP  DTS  DCAL  \
# 0       NaN  19.2031   NaN  1.613886  ... NaN   96.461990  NaN   NaN
# 1       NaN  19.2031   NaN  1.574376  ... NaN   96.454399  NaN   NaN
# 2       NaN  19.2031   NaN  1.436627  ... NaN   96.446686  NaN   NaN
# 3       NaN  19.2031   NaN  1.276094  ... NaN  161.170166  NaN   NaN
# 4       NaN  19.2031   NaN  1.204704  ... NaN  172.489120  NaN   NaN
#
#        DRHO  MUDWEIGHT  RMIC  ROPA  RXO  PRED_LITHOLOGY
# ...

# %%
for w in df.WELL.unique():
    create_CPI(df, w, 'DEPTH_MD', log_dict, top_depth=None, bottom_depth=None,
               log_shading_dict=log_shading_dict,
               plot_litho={'PRED_LITHOLOGY': litho_dict, 'GROUP_num':group_dict},
               plot_full_litho_legend=False, scaled_plot=False)
# Out:
# <ipython-input-15-327119759173>:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = df[df.WELL==well][df[depth_col]>=top_depth][df[depth_col]<=bottom_depth]
# <ipython-input-15-327119759173>:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = df[df.WELL==well][df[depth_col]>=top_depth][df[depth_col]<=bottom_depth]
# <ipython-input-15-327119759173>:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = df[df.WELL==well][df[depth_col]>=top_depth][df[depth_col]<=bottom_depth]
# <ipython-input-15-327119759173>:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = df[df.WELL==well][df[depth_col]>=top_depth][df[depth_col]<=bottom_depth]
# <ipython-input-15-327119759173>:95: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data = df[df.WELL==well][df[depth_col]>=top_depth][df[depth_col]<=bottom_depth]
# ...

# %%
print(f'The number of datapoints ("rows") per lithology\n{"-"*47}')
for l in litho_dict.keys():
    print(f'{litho_dict[l][0]:>18}:{sum(df.PRED_LITHOLOGY==l):>8}')
# Out:
# The number of datapoints ("rows") per lithology
# -----------------------------------------------
#          Sandstone:   22419
#              Shale:   97853
#    Sandstone/Shale:    6949
#          Limestone:    6951
#              Chalk:      11
#           Dolomite:       0
#               Marl:     707
#          Anhydrite:       0
#             Halite:       0
#               Coal:     868
#           Basement:       0
#               Tuff:    1028

# %%
print(f'The number of datapoints ("rows") per GROUP\n{"-"*47}')
for g in group_dict.keys():
    print(f'{group_dict[g][0]:>18}:{sum(df.GROUP_num==g):>18}')
# Out:
# The number of datapoints ("rows") per GROUP
# -----------------------------------------------
#       NORDLAND GP.:             14605
#      HORDALAND GP.:             27149
#       ROGALAND GP.:             11609
#       SHETLAND GP.:             46684
#   CROMER KNOLL GP.:              6365
#         VIKING GP.:              5418
#           TYNE GP.:                 0
#      BOKNFJORD GP.:                 0
#       VESTLAND GP.:              2682
#         DUNLIN GP.:             15390
#           BAAT GP.:              6282
#          HEGRE GP.:               477
#      ZECHSTEIN GP.:               125
#   ROTLIEGENDES GP.:                 0
