# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import functionality from other notebooks

# %%
# %run PLOTTING_FUNCTIONS.ipynb

# %%
# %run COSMETICS_DICTIONARIES.ipynb

# %%
# %run SOME_PREPROCESSING.ipynb

# %% [markdown]
# ### Plot bar-charts for FORMATION, GROUP, CONFIDENCE and NEW_GROUP per LITHOLOGY

# %%
bar_chart_percent_lithology(df, 'GROUP', 'FORCE_2020_LITHOFACIES_LITHOLOGY', group_dict, litho_dict,
                            normalized=False, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'GROUP', 'FORCE_2020_LITHOFACIES_LITHOLOGY', group_dict, litho_dict,
                            normalized=True, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'FORMATION', 'FORCE_2020_LITHOFACIES_LITHOLOGY', fm_dict, litho_dict,
                            normalized=False, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'FORMATION', 'FORCE_2020_LITHOFACIES_LITHOLOGY', fm_dict, litho_dict,
                            normalized=True, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'CONFIDENCE', 'FORCE_2020_LITHOFACIES_LITHOLOGY', conf_dict, litho_dict,
                            normalized=False, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'CONFIDENCE', 'FORCE_2020_LITHOFACIES_LITHOLOGY', conf_dict, litho_dict,
                            normalized=True, width=1, figsize=(12, 8), save_plot=True)

# %% [markdown]
# #### There are inconsistencies between FORMATION and GROUP in the original dataset. Assuming the FORMATIONs are correct, new (stratigraphically correct) GROUPs have been assigned in a variable named "new_GROUP"

# %%
bar_chart_percent_lithology(df, 'new_GROUP', 'FORCE_2020_LITHOFACIES_LITHOLOGY', group_dict, litho_dict,
                            normalized=False, width=1, figsize=(12, 8), save_plot=True)

# %%
bar_chart_percent_lithology(df, 'new_GROUP', 'FORCE_2020_LITHOFACIES_LITHOLOGY', group_dict, litho_dict,
                            normalized=True, width=1, figsize=(12, 8), save_plot=True)
