# %%
# %run ./PLOTTING_FUNCTIONS.ipynb

# %%
# %run ./SOME_PREPROCESSING.ipynb

# %%
create_legend(litho_dict,'LITHOLOGY', save_plot=True)

# %%
create_legend(group_dict,'STRAT. GP', save_plot=True)

# %%
create_legend(fm_dict,'STRAT. FM', save_plot=True)

# %%
create_legend(high_constrast_fm_dict,'HI CONTR. STRAT. FM', save_plot=True)

# %%
create_legend(conf_dict,'CONFIDENCE', save_plot=True)
