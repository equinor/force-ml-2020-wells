# %%
import pandas as pd
import numpy as np

# %%
# %run PLOTTING_FUNCTIONS.ipynb

# %%
# %run COSMETICS_DICTIONARIES.ipynb

# %%
# %run SOME_PREPROCESSING.ipynb

# %%
# Gardner equation:
syn_DTC = 1e6/((df.RHOB/0.23)**4)
fig = plt.figure(figsize=(6,6))
plt.plot(df.DTC, syn_DTC,'r.', alpha=0.01)
plt.plot([40,240],[40,240],'k:')
plt.xlim([40,240])
plt.ylim([40,240])
plt.show()

# %%
syn_DTC = 1e6/((df.RHOB/0.185)**3.7)
fig = plt.figure(figsize=(6,6))
plt.plot(df.DTC, syn_DTC,'r.', alpha=0.01)
plt.plot([40,240],[40,240],'k:')
plt.xlim([40,240])
plt.ylim([40,240])
plt.show()
